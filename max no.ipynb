# %%
a=int(input())
b=int(input())
c=int(input())
if(a>b and a>c):
    print("a is large no")
elif(b>a and b>c):
    print("b is large no")
else:
 print("c is large no")
# Out:
#  23
#  24
#  12
# b is larhe no
